# %%
pip install pandas numpy

# %%
#QUESTÃO 1
import pandas as pd

vendido = [150, 200, 120, 300, 250]
qtd_produtos_semana = pd.Series([150, 200, 120, 300, 250],
                                index=['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'])
print(qtd_produtos_semana)

# %%
#QUESTÃO 2
catalogo = {
    'Título' : ['Star Wars: O Despertar da Força', 
                'Harry Potter e o Cálice de Fogo', 
                'Interestellar', 'A Sociedade dos Poetas Mortos'],

    'Ano de Lançamento' : [2015, 2005, 2014, 1989],
    
    'Gênero' : ['Ficção científica', 'Fantasia', 'Aventura', 'Drama']
}

df_catalogo = pd.DataFrame(catalogo)
print(df_catalogo)

# %%
#QUESTÃO 3
print(df_catalogo['Título'])

# %%
#Qual foi o tipo de estrutura de dados que o Pandas retornou ao mostrar apenas uma coluna?
#O tipo de dado retornado pelo Pandas foi do tipo Series, já que um DataFrame seriam na verdade
#Series juntas, mas organizadas em várias colunas.
